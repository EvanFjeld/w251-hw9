# %%
import os
import random
import shutil
import time
import warnings

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim

import torch.utils.data
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

# %%
SEED=1

# %%
random.seed(SEED)
torch.manual_seed(SEED)
cudnn.deterministic = True

# %%
START_EPOCH = 0

# %% [markdown]
# ### Set the architecture to resnet 18 below

# %%
##########################
ARCH = 'resnet18'# set the architecture to RESNET 18
# please look up how to do that
########################
EPOCHS = 5
LR = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
PRINT_FREQ = 50
TRAIN_BATCH=128
VAL_BATCH=128
WORKERS=2

# %% [markdown]
# ### Check if cuda is available here

# %%
# check if cuda is available in this cell
# if it is not available, you should not go forward!
print("CUDA is available:", torch.cuda.is_available())
# Out:
# CUDA is available: True

# %% [markdown]
# ### Assign your GPU below

# %%
# Assign your GPU in this cell
GPU = None

# %%
# set your active device to your GPU in this cell
device = torch.device("cuda")

# %%
# enable algorithm optimization
cudnn.benchmark = True

# %% [markdown]
# ## Download the data from Kaggle

# %%
# download dataset from kaggle
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p ~/.kaggle
# !cp "drive/MyDrive/w251/Evan_Fjeld_hw5/kaggle.json" ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d mengcius/cinic10

# !mkdir drive/MyDrive/w251/Evan_Fjeld_hw5/data
# !unzip cinic10.zip -d drive/MyDrive/w251/Evan_Fjeld_hw5/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1173.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_11766.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_11887.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1191.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1192.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1195.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1207.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_12128.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1214.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1237.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1248.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1261.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1264.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1292.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1313.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1319.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_13311.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1355.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_13648.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_13730.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_13862.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_14237.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1429.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_14786.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_14991.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_15378.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1544.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_15484.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_15817.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_16694.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1701.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1722.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1728.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1737.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1792.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1798.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1903.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1909.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1927.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1935.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1989.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_1999.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2003.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2005.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2006.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2012.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2072.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2086.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2100.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2101.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2112.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2128.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2131.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2135.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2152.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2156.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2157.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_219.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2198.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2230.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2244.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2249.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2258.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2264.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2274.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2280.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2291.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2305.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2324.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2335.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2376.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2395.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2473.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2475.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2479.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2489.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2503.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2506.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2554.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2591.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2601.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2610.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2619.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_270.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2706.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2787.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2795.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2849.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2859.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2870.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2940.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2960.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_2985.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3047.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3105.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3141.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3162.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3163.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3183.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3193.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3239.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3289.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3319.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3323.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3343.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3367.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3421.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3437.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3444.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3459.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3478.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_348.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3498.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3499.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3500.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3525.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3566.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3573.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3585.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3593.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3608.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3623.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3657.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3658.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3670.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3673.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3677.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3683.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3690.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3692.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3703.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3750.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3753.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3758.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3763.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3764.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3769.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3773.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3781.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3821.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3855.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3869.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_389.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3896.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3902.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3903.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3907.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_3940.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4001.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4033.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4048.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4102.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4108.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_411.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4113.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4133.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4135.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4181.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4240.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4281.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4322.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4342.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4346.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4350.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4358.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_44.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4446.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4499.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4560.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4598.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4601.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4624.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_465.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4790.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4806.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4974.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_4988.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_499.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_501.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5055.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5093.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5120.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5158.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5233.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_526.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5263.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5318.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5476.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5482.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5550.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5612.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_563.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5659.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5697.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5727.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5738.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5739.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5770.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5780.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5782.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5939.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5959.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5960.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_5997.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6030.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6039.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6057.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6075.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_615.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6238.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6335.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_634.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6341.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_6373.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_64.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03632852_
png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03690473_9587.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03690473_9588.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03690473_9697.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03690473_9714.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n03690473_9999.png
# ...
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4315.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4331.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4388.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_441.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4434.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4474.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4478.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4487.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4591.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4597.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4613.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4614.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4679.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4692.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4756.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4758.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_476.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_480.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4817.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4821.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4822.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4849.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_488.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4881.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4935.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_4971.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_50.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5000.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5032.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5065.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5134.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5147.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5183.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5205.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5225.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5233.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5235.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5346.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5432.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5440.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5467.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5499.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5513.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5529.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5535.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5598.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5610.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5620.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5669.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5675.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5754.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5764.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5817.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5827.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5847.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5855.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5874.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5883.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5886.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5913.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5966.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5994.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_5999.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6034.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6045.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6062.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_608.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6122.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6146.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6150.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6211.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6212.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_623.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6280.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6308.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6330.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6333.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6377.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6397.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_643.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6439.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6460.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6469.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6480.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6489.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6514.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6539.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6563.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6570.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6575.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6577.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6612.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_662.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6666.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6667.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6720.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6730.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6739.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6789.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_68.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_6854.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_698.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_703.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7048.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7087.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7103.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7197.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7257.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7271.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7282.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7288.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7293.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7302.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7326.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_74.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7409.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_745.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7469.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7524.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_755.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7585.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7650.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7690.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7697.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7735.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7761.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7790.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7797.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7895.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_7899.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_793.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_801.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8046.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8050.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8180.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8181.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_82.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8228.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8308.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_832.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8342.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8383.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8427.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_844.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8467.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8520.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8543.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8749.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8781.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8821.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8858.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8892.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8909.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_8935.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_894.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_899.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9018.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9052.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9075.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9095.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9147.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9151.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9170.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9189.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9311.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9346.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9401.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9435.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_945.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9471.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9477.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9499.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9500.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9534.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9535.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9539.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9564.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9570.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9573.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9601.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9622.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_969.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9781.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_98.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9800.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9801.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9830.png
#   inflating: drive/MyDrive/w251/Evan_Fjeld_hw5/data/valid/truck/n04520170_9880.png

# %%
#!rm -r drive/MyDrive/w251/Evan_Fjeld_hw5/data
# Out:
# rm: cannot remove 'drive/MyDrive/w251/Evan_Fjeld_hw5/data/test': No such file or directory

# %% [markdown]
# ### Fill in the heart of the train section below

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter('Time', ':6.3f')
    data_time = AverageMeter('Data', ':6.3f')
    losses = AverageMeter('Loss', ':.4e')
    top1 = AverageMeter('Acc@1', ':6.2f')
    top5 = AverageMeter('Acc@5', ':6.2f')
    progress = ProgressMeter(
        len(train_loader),
        [batch_time, data_time, losses, top1, top5],
        prefix="Epoch: [{}]".format(epoch))

    ######################
    # switch model to train mode here
    model.train()
    ################

    end = time.time()
    for i, (images, target) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        #####################
        # send the images to cuda device
        images = images.to(device)
        # send the target to cuda device
        target = target.to(device)

        # compute output
        output = model(images)

        # compute loss 
        loss = criterion(output, target)


        # measure accuracy and record loss
        acc1, acc5 = accuracy(output, target, topk=(1, 5))
        losses.update(loss.item(), images.size(0))
        top1.update(acc1[0], images.size(0))
        top5.update(acc5[0], images.size(0))

        # compute gradient and do SGD step
        
        #### zero out gradients in the optimier
        optimizer.zero_grad()
        
        ## backprop!
        loss.backward()
        
        # update the weights!
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % PRINT_FREQ == 0:
            progress.display(i)

# %% [markdown]
# #### Fill in the validate section below

# %%
def validate(val_loader, model, criterion):
    batch_time = AverageMeter('Time', ':6.3f')
    losses = AverageMeter('Loss', ':.4e')
    top1 = AverageMeter('Acc@1', ':6.2f')
    top5 = AverageMeter('Acc@5', ':6.2f')
    progress = ProgressMeter(
        len(val_loader),
        [batch_time, losses, top1, top5],
        prefix='Test: ')

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        end = time.time()
        for i, (images, target) in enumerate(val_loader):
            
            
            ### send the images and target to cuda
            images = images.cuda()
            target = target.cuda()

            # compute output
            output = model(images)

            # compute loss
            loss = criterion(output, target)


            # measure accuracy and record loss
            acc1, acc5 = accuracy(output, target, topk=(1, 5))
            losses.update(loss.item(), images.size(0))
            top1.update(acc1[0], images.size(0))
            top5.update(acc5[0], images.size(0))

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            if i % PRINT_FREQ == 0:
                progress.display(i)

        # TODO: this should also be done with the ProgressMeter
        print(' * Acc@1 {top1.avg:.3f} Acc@5 {top5.avg:.3f}'
              .format(top1=top1, top5=top5))

    return top1.avg

# %% [markdown]
# ### Save the checkpoint

# %%
def save_checkpoint(state, is_best, filename='checkpoint.pth.tar'):
    # save the model state!
    torch.save(state, filename)
    
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)

# %%
class ProgressMeter(object):
    def __init__(self, num_batches, meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def display(self, batch):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        print('\t'.join(entries))

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = '{:' + str(num_digits) + 'd}'
        return '[' + fmt + '/' + fmt.format(num_batches) + ']'

# %%
# if we are adjusting the LR manually use this
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = LR * (0.1 ** (epoch // 30))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
cinic_mean_RGB = [0.47889522, 0.47227842, 0.43047404]
cinic_std_RGB = [0.24205776, 0.23828046, 0.25874835]

# %%
normalize = transforms.Normalize(mean=cinic_mean_RGB, std=cinic_std_RGB)

# %%
IMG_SIZE = 32
# IMG_SIZE = 224

# %% [markdown]
# ### Initialize the model using the architecture you selected above

# %%
# select the model
model = models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# ### Send the model to the cuda device

# %%
# send the model to the cuda device.. 
model = model.to(device)

# %% [markdown]
# ### Instantiate the loss to cross entropy

# %%
# use the cross-entropy loss
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### Instantiate the optimizer to SGD

# %%
# use SGD .. use the momentum and weight decay vars
optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# #### Create the learning rate scheduler

# %%
# use CosineAnnealingLR
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=0.00001)

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(cinic_mean_RGB, cinic_std_RGB),
])

# %% [markdown]
# ### Create the train dataset object

# %%
# use torchvision.datasets.CIFAR10
#train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
train_dataset = datasets.ImageFolder(root='drive/MyDrive/w251/Evan_Fjeld_hw5/data/train', transform=transform_train)

# %%
transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cinic_mean_RGB, cinic_std_RGB),
])

# %% [markdown]
# ### Create the val dataset object

# %%
# use torchvision.datasets.CIFAR10
# val_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_val)
val_dataset = datasets.ImageFolder(root='drive/MyDrive/w251/Evan_Fjeld_hw5/data/test', transform=transform_val)

# %% [markdown]
# ### Create the train dataloader

# %%
# fill this in
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=TRAIN_BATCH, shuffle=True, num_workers=WORKERS)

# %% [markdown]
# ### Create the c

# %%
# fill this in..
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=VAL_BATCH, shuffle=False, num_workers=WORKERS)

# %%
best_acc1 = 0

# %%
epochs = []
results = []
for epoch in range(START_EPOCH, EPOCHS):
#    adjust_learning_rate(optimizer, epoch)

    # train for one epoch
    train(train_loader, model, criterion, optimizer, epoch)

    # evaluate on validation set
    acc1 = validate(val_loader, model, criterion)

    # remember best acc@1 and save checkpoint
    is_best = acc1 > best_acc1
    best_acc1 = max(acc1, best_acc1)


    save_checkpoint({
        'epoch': epoch + 1,
        'arch': ARCH,
        'state_dict': model.state_dict(),
        'best_acc1': best_acc1,
        'optimizer' : optimizer.state_dict(),
    }, is_best)

    # save Acc@1 as array for each epoc
    epochs.append(epoch)
    results.append(scheduler.get_last_lr())
    
    scheduler.step()
    print('lr: ' + str(scheduler.get_last_lr()))
# Out:
# Epoch: [0][  0/704]	Time  0.620 ( 0.620)	Data  0.586 ( 0.586)	Loss 1.7814e+00 (1.7814e+00)	Acc@1  35.94 ( 35.94)	Acc@5  84.38 ( 84.38)
# Epoch: [3][500/704]	Time  0.047 ( 0.204)	Data  0.001 ( 0.170)	Loss 1.3814e+00 (1.4125e+00)	Acc@1  50.78 ( 48.26)	Acc@5  94.53 ( 92.89)
# Epoch: [3][550/704]	Time  0.047 ( 0.202)	Data  0.001 ( 0.168)	Loss 1.4659e+00 (1.4116e+00)	Acc@1  46.09 ( 48.34)	Acc@5  89.06 ( 92.88)
# Epoch: [3][600/704]	Time  0.046 ( 0.203)	Data  0.001 ( 0.168)	Loss 1.4465e+00 (1.4101e+00)	Acc@1  47.66 ( 48.40)	Acc@5  92.19 ( 92.90)
# Epoch: [3][650/704]	Time  0.041 ( 0.204)	Data  0.001 ( 0.168)	Loss 1.3327e+00 (1.4094e+00)	Acc@1  55.47 ( 48.50)	Acc@5  93.75 ( 92.89)
# Epoch: [3][700/704]	Time  0.053 ( 0.203)	Data  0.000 ( 0.168)	Loss 1.4595e+00 (1.4077e+00)	Acc@1  46.88 ( 48.55)	Acc@5  96.09 ( 92.92)
# Test: [  0/704]	Time  0.450 ( 0.450)	Loss 1.0300e+00 (1.0300e+00)	Acc@1  62.50 ( 62.50)	Acc@5  92.97 ( 92.97)
# Test: [ 50/704]	Time  0.199 ( 0.160)	Loss 1.0883e+00 (1.1267e+00)	Acc@1  55.47 ( 58.04)	Acc@5  96.09 ( 93.87)
# Test: [100/704]	Time  0.183 ( 0.168)	Loss 8.0688e-01 (1.1125e+00)	Acc@1  71.88 ( 60.30)	Acc@5  96.88 ( 94.08)
# Test: [150/704]	Time  0.391 ( 0.168)	Loss 1.0607e+00 (1.1587e+00)	Acc@1  66.41 ( 60.16)	Acc@5  98.44 ( 93.47)
# Test: [200/704]	Time  0.309 ( 0.168)	Loss 1.3447e+00 (1.2190e+00)	Acc@1  47.66 ( 57.01)	Acc@5  99.22 ( 94.34)
# Test: [250/704]	Time  0.280 ( 0.169)	Loss 1.8046e+00 (1.2910e+00)	Acc@1  30.47 ( 53.26)	Acc@5  94.53 ( 94.84)
# Test: [300/704]	Time  0.264 ( 0.168)	Loss 2.1503e+00 (1.3854e+00)	Acc@1  16.41 ( 49.24)	Acc@5  94.53 ( 95.10)
# Test: [350/704]	Time  0.386 ( 0.169)	Loss 1.7596e+00 (1.4754e+00)	Acc@1  32.03 ( 46.30)	Acc@5  97.66 ( 94.91)
# Test: [400/704]	Time  0.433 ( 0.169)	Loss 1.8518e+00 (1.5053e+00)	Acc@1  27.34 ( 44.64)	Acc@5  99.22 ( 95.16)
# Test: [450/704]	Time  0.290 ( 0.168)	Loss 6.9313e-01 (1.4892e+00)	Acc@1  79.69 ( 45.47)	Acc@5  96.88 ( 95.32)
# Test: [500/704]	Time  0.319 ( 0.169)	Loss 1.9983e+00 (1.4305e+00)	Acc@1  37.50 ( 48.12)	Acc@5  71.09 ( 95.16)
# Test: [550/704]	Time  0.283 ( 0.167)	Loss 1.7801e+00 (1.4709e+00)	Acc@1  46.88 ( 47.55)	Acc@5  80.47 ( 93.46)
# Test: [600/704]	Time  0.193 ( 0.167)	Loss 1.2303e+00 (1.4406e+00)	Acc@1  67.19 ( 49.09)	Acc@5  87.50 ( 93.17)
# Test: [650/704]	Time  0.382 ( 0.168)	Loss 1.3316e+00 (1.4222e+00)	Acc@1  51.56 ( 49.98)	Acc@5  92.19 ( 93.01)
# Test: [700/704]	Time  0.225 ( 0.167)	Loss 1.7214e+00 (1.4414e+00)	Acc@1  27.34 ( 49.02)	Acc@5  91.41 ( 92.70)
#  * Acc@1 48.956 Acc@5 92.699
# lr: [0.09045180463377553]
# Epoch: [4][  0/704]	Time  0.674 ( 0.674)	Data  0.632 ( 0.632)	Loss 1.4474e+00 (1.4474e+00)	Acc@1  46.88 ( 46.88)	Acc@5  94.53 ( 94.53)
# Epoch: [4][ 50/704]	Time  0.329 ( 0.219)	Data  0.306 ( 0.178)	Loss 1.5262e+00 (1.4045e+00)	Acc@1  45.31 ( 49.02)	Acc@5  91.41 ( 92.85)
# Epoch: [4][100/704]	Time  0.459 ( 0.213)	Data  0.436 ( 0.172)	Loss 1.5781e+00 (1.3901e+00)	Acc@1  38.28 ( 49.61)	Acc@5  90.62 ( 92.86)
# Epoch: [4][150/704]	Time  0.445 ( 0.204)	Data  0.386 ( 0.165)	Loss 1.2544e+00 (1.3814e+00)	Acc@1  55.47 ( 49.96)	Acc@5  96.88 ( 92.99)
# Epoch: [4][200/704]	Time  0.416 ( 0.204)	Data  0.365 ( 0.166)	Loss 1.3283e+00 (1.3798e+00)	Acc@1  56.25 ( 50.08)	Acc@5  96.09 ( 93.12)
# Epoch: [4][250/704]	Time  0.383 ( 0.204)	Data  0.355 ( 0.165)	Loss 1.3324e+00 (1.3765e+00)	Acc@1  53.12 ( 50.34)	Acc@5  91.41 ( 93.15)
# Epoch: [4][300/704]	Time  0.418 ( 0.204)	Data  0.362 ( 0.165)	Loss 1.4222e+00 (1.3698e+00)	Acc@1  46.88 ( 50.52)	Acc@5  91.41 ( 93.33)
# Epoch: [4][350/704]	Time  0.275 ( 0.201)	Data  0.251 ( 0.163)	Loss 1.3640e+00 (1.3694e+00)	Acc@1  50.00 ( 50.44)	Acc@5  93.75 ( 93.35)
# Epoch: [4][400/704]	Time  0.325 ( 0.202)	Data  0.302 ( 0.164)	Loss 1.2304e+00 (1.3700e+00)	Acc@1  57.03 ( 50.41)	Acc@5  95.31 ( 93.31)
# Epoch: [4][450/704]	Time  0.309 ( 0.202)	Data  0.287 ( 0.164)	Loss 1.2322e+00 (1.3673e+00)	Acc@1  53.91 ( 50.49)	Acc@5  94.53 ( 93.33)
# Epoch: [4][500/704]	Time  0.402 ( 0.201)	Data  0.366 ( 0.163)	Loss 1.2480e+00 (1.3635e+00)	Acc@1  59.38 ( 50.67)	Acc@5  92.97 ( 93.38)
# Epoch: [4][550/704]	Time  0.368 ( 0.201)	Data  0.343 ( 0.163)	Loss 1.3562e+00 (1.3600e+00)	Acc@1  52.34 ( 50.76)	Acc@5  90.62 ( 93.41)
# Epoch: [4][600/704]	Time  0.423 ( 0.201)	Data  0.395 ( 0.163)	Loss 1.5777e+00 (1.3590e+00)	Acc@1  46.09 ( 50.81)	Acc@5  91.41 ( 93.43)
# Epoch: [4][650/704]	Time  0.372 ( 0.202)	Data  0.339 ( 0.163)	Loss 1.2889e+00 (1.3576e+00)	Acc@1  54.69 ( 50.93)	Acc@5  92.19 ( 93.42)
# Epoch: [4][700/704]	Time  0.266 ( 0.200)	Data  0.243 ( 0.162)	Loss 1.3675e+00 (1.3542e+00)	Acc@1  53.91 ( 51.05)	Acc@5  92.97 ( 93.44)
# Test: [  0/704]	Time  0.464 ( 0.464)	Loss 5.9192e-01 (5.9192e-01)	Acc@1  80.47 ( 80.47)	Acc@5  98.44 ( 98.44)
# Test: [ 50/704]	Time  0.131 ( 0.179)	Loss 5.4562e-01 (6.4321e-01)	Acc@1  83.59 ( 77.73)	Acc@5  97.66 ( 96.81)
# Test: [100/704]	Time  0.121 ( 0.176)	Loss 6.7646e-01 (6.9586e-01)	Acc@1  78.12 ( 76.24)	Acc@5  97.66 ( 96.96)
# Test: [150/704]	Time  0.029 ( 0.169)	Loss 1.1075e+00 (8.2391e-01)	Acc@1  63.28 ( 71.93)	Acc@5  97.66 ( 96.22)
# Test: [200/704]	Time  0.013 ( 0.171)	Loss 1.2669e+00 (9.3527e-01)	Acc@1  56.25 ( 67.90)	Acc@5  98.44 ( 96.32)
# Test: [250/704]	Time  0.023 ( 0.168)	Loss 2.1937e+00 (1.1269e+00)	Acc@1  12.50 ( 58.87)	Acc@5  84.38 ( 95.50)
# Test: [300/704]	Time  0.012 ( 0.169)	Loss 1.6542e+00 (1.2537e+00)	Acc@1  35.94 ( 53.61)	Acc@5  96.09 ( 95.20)
# Test: [350/704]	Time  0.027 ( 0.169)	Loss 1.5459e+00 (1.2872e+00)	Acc@1  39.84 ( 52.73)	Acc@5  97.66 ( 95.52)
# Test: [400/704]	Time  0.012 ( 0.168)	Loss 1.7184e+00 (1.3372e+00)	Acc@1  34.38 ( 50.68)	Acc@5  98.44 ( 95.38)
# Test: [450/704]	Time  0.016 ( 0.168)	Loss 7.3637e-01 (1.3335e+00)	Acc@1  80.47 ( 50.86)	Acc@5  94.53 ( 95.30)
# Test: [500/704]	Time  0.015 ( 0.166)	Loss 1.5584e+00 (1.2962e+00)	Acc@1  53.12 ( 52.88)	Acc@5  81.25 ( 94.99)
# Test: [550/704]	Time  0.013 ( 0.167)	Loss 1.8213e+00 (1.3288e+00)	Acc@1  44.53 ( 52.21)	Acc@5  75.00 ( 93.78)
# Test: [600/704]	Time  0.026 ( 0.167)	Loss 1.1369e+00 (1.3081e+00)	Acc@1  64.06 ( 53.16)	Acc@5  94.53 ( 93.71)
# Test: [650/704]	Time  0.166 ( 0.166)	Loss 1.4215e+00 (1.2943e+00)	Acc@1  48.44 ( 53.68)	Acc@5  92.19 ( 93.83)
# Test: [700/704]	Time  0.301 ( 0.167)	Loss 1.8728e+00 (1.3371e+00)	Acc@1  23.44 ( 52.00)	Acc@5  95.31 ( 93.60)
#  * Acc@1 51.909 Acc@5 93.609
# lr: [0.08535680352542147]

# %%
import matplotlib.pyplot as plt

plt.plot(epochs, results)
plt.xlabel('Epochs')
plt.ylabel('Performance')
plt.title('Line Plot')
plt.show()
